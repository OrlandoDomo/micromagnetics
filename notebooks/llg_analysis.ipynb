# %%
import discretisedfield.tools as dft
import numpy as np
import imageio.v3 as iio

from pathlib import Path

import micromagneticdata as md
import holoviews as hv

hv.extension("matplotlib", logo=False)
hv.output(widget_location="bottom")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2cce18a2-75ce-4aab-96a7-341021783dec'>
#   <div id="adee548a-0b5c-486b-96c1-c5508e0e701c" data-root-id="2cce18a2-75ce-4aab-96a7-341021783dec" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
data = md.Data(
    name="saf_skyrmion_hysteresis_llg",
    dirname="../results/saf_skyrmion-0.8nm-d_1-hysteresis-llg-old/saf_skyrmion-300nm-280kA_m-200steps-2ns-100K"
)

# %%
data.info
# Out:
#    drive_number        date      time           start_time adapter  \
# 0             0  2025-08-05  13:29:12  2025-08-05T13:29:12  oommfc
# 1             1  2025-08-05  14:30:38  2025-08-05T14:30:38  oommfc
# 2             2  2025-08-05  14:50:10  2025-08-05T14:50:10  oommfc
#
#   adapter_version      driver             t    n  n_threads  \
# 0          0.66.0  TimeDriver  2.000000e-09  200          8
# 1          0.66.0  TimeDriver  2.000000e-09  200          8
# 2          0.66.0  TimeDriver  2.000000e-09  200          8
#
#               end_time elapsed_time  success  info.json
# 0  2025-08-05T13:44:02     00:14:51     True  available
# 1  2025-08-05T14:34:11     00:03:34     True  available
# 2  2025-08-05T17:15:20     02:25:11     True  available

# %%
time_drive = data[2]

# %%
time_drive.table.data.E
#time_drive.table.data['DMI_Cnv_z:dmi:Energy']
# Out:
# 0      1.887615e-16
# 1      1.868412e-16
# 2      1.856756e-16
# 3      1.853118e-16
# 4      1.854361e-16
#            ...
# 195    1.818951e-16
# 196    1.824644e-16
# 197    1.818887e-16
# 198    1.823376e-16
# 199    1.817570e-16
# Name: E, Length: 200, dtype: float64

# %%
time_drive.register_callback(lambda field: field.orientation).hv(kdims=["x", "y"])
# Out:
# :DynamicMap   [z,t]
#    :Overlay
#       .Image.I       :Image   [x,y]   (field)
#       .VectorField.I :VectorField   [x,y]   (angle,mag)

# %%
hysteresis_data = md.Data(
    name="saf_skyrmion_hysteresis_llg",
    dirname="../results/saf_skyrmion-0.8nm-d_1-hysteresis-llg-old/saf_skyrmion-300nm-280kA_m-200steps-2ns-100K-hysteresis"
)

# %%
drive = hysteresis_data[0]

# %%
drive.table.mpl(x="Bz_hysteresis", y=["mz"], ax=ax)

# %%
drive.x = "stage"
Ms = np.max(np.abs(drive.m0.norm.array))

drive.register_callback(lambda field: field.z).hv(
    kdims=["x", "y"], scalar_kw={"clim": (-Ms, Ms)}
)
# Out:
# :DynamicMap   [z,stage]
#    :Image   [x,y]   (field)

# %%
HYSTERESIS_IMAGES = '../images/hysteresis-old/saf_skyrmion-300nm-280kA_m-hysteresis'

images = list()
for file in Path(HYSTERESIS_IMAGES).iterdir():
    if not file.is_file():
        continue
    print(file.name)
    images.append(iio.imread(file))

iio.imwrite('hysteresis_stages.gif', images, fps=2)
# Out:
# skyrmion-300nm-280kA_m-step_01.png
# skyrmion-300nm-280kA_m-step_02.png
# skyrmion-300nm-280kA_m-step_03.png
# skyrmion-300nm-280kA_m-step_04.png
# skyrmion-300nm-280kA_m-step_05.png
# skyrmion-300nm-280kA_m-step_06.png
# skyrmion-300nm-280kA_m-step_07.png
# skyrmion-300nm-280kA_m-step_08.png
# skyrmion-300nm-280kA_m-step_09.png
# skyrmion-300nm-280kA_m-step_10.png
# skyrmion-300nm-280kA_m-step_11.png
# skyrmion-300nm-280kA_m-step_12.png
# skyrmion-300nm-280kA_m-step_13.png
# skyrmion-300nm-280kA_m-step_14.png
# skyrmion-300nm-280kA_m-step_15.png
# skyrmion-300nm-280kA_m-step_16.png
# skyrmion-300nm-280kA_m-step_17.png
# skyrmion-300nm-280kA_m-step_18.png
# skyrmion-300nm-280kA_m-step_19.png
# skyrmion-300nm-280kA_m-step_20.png
# skyrmion-300nm-280kA_m-step_21.png
# skyrmion-300nm-280kA_m-step_22.png
# skyrmion-300nm-280kA_m-step_23.png
# skyrmion-300nm-280kA_m-step_24.png
# skyrmion-300nm-280kA_m-step_25.png
# skyrmion-300nm-280kA_m-step_26.png
# skyrmion-300nm-280kA_m-step_27.png
# ...
