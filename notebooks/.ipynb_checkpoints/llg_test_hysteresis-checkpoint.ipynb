# %%
import oommfc as oc
import micromagneticdata as md
import discretisedfield as df
import functools
import matplotlib.pyplot as plt
import micromagneticmodel as mm
import os 
import re

# %%
def get_mesh(D: float, w: float):
    r = D / 2
    p10 = (-r, -r, 0)
    p20 = (r, r, 16.8e-9)

    region = df.Region(p1=p10, p2=p20)
    subregions = {
        "bottom": df.Region(p1=p10, p2=(r, r, 8e-9)),
        "spacer": df.Region(p1=(-r, -r, 8e-9), p2=(r, r, (8 + w) * 1e-9)),
        "top": df.Region(p1=(-r, -r, (8 + w) * 1e-9), p2=p20),
    }

    mesh = df.Mesh(region=region, cell=(3e-9, 3e-9, 8e-10), subregions=subregions)

    return mesh


def Ms_init(pos, Ms, D):
    x, y, z = pos
    r = D / 2
    if (x**2 + y**2) ** 0.5 < r:
        if z < 8e-9:
            return -Ms
        else:
            return Ms
    else:
        return 0


def m_init(pos, d):
    x, y, z = pos
    r = d / 2
    if (x**2 + y**2) ** 0.5 < r:
        return (0, 0, -1)
    else:
        return (0, 0, 1)

# %%
D = 300e-9
w = 0.8
Ms = 280e3
mesh = get_mesh(D, w)
mesh.mpl.subregions()

# %%
RESULTS_PATH_HYSTERESIS = "../results/saf_skyrmion-0.8nm-d_1-hysteresis-llg"
d = 40e-9
Ms_fun = functools.partial(Ms_init, Ms=Ms, D=D)
m_fun = functools.partial(m_init, d=d)

## ENERGY TERMS
A = 1e-11  # J/m
sigma = -0.3e-3  # J/m^2
K = 0.1e6  # J/m^3
dmi = 1e-3  # J/m^2
system = mm.System(name="saf_skyrmion_hysteresis_llg")
system.energy = (
    mm.Exchange(A=A)
    + mm.RKKY(sigma=sigma, sigma2=0, subregions=["bottom", "top"])
    + mm.UniaxialAnisotropy(K=K, u=(0, 0, 1))
    + mm.Demag()
    + mm.DMI(D=dmi, crystalclass="Cnv_z")
)

## DYNAMICS
alpha = 0.3
gamma0 = 2.211e5 # m/As
system.dynamics = mm.Precession(gamma0=gamma0) + mm.Damping(alpha=alpha)

## MAGNETIZATION
norm = {"bottom": Ms_fun, "top": Ms_fun, "spacer": 0}
system.m = df.Field(mesh, nvdim=3, value=m_fun, norm=norm, valid="norm")

## DRIVING
sim_time = 0.1 # ns
dm_dt = 
md = oc.TimeDriver()
md.drive(
    system,
    t=sim_time*1e-9,
    n=200,
    dirname=f"{RESULTS_PATH_HYSTERESIS}/saf_skyrmion-{D / 1e-9:.0f}nm-{Ms / 1e3:.0f}kA_m-200steps-{sim_time}ns",
)
# Out:
# Running OOMMF (ExeOOMMFRunner)[2025/07/30 15:58]... (453.4 s)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
system.m.sel(z=12e-9).z.mpl.scalar(ax=ax, cmap="bwr", colorbar_label="z-component")
system.m.sel(z=12e-9).resample((25, 25)).mpl.vector(
    ax=ax, use_color=False, color="black"
)

# %%
Hmin = (0, 0, -4 / mm.consts.mu0)
Hmax = (0, 0, 4 / mm.consts.mu0)

hd = oc.HysteresisDriver()
hd.drive(
    system,
    dirname=f"{RESULTS_PATH_HYSTERESIS}/saf_skyrmion-{D / 1e-9:.0f}nm-{Ms / 1e3:.0f}kA_m-200steps-{sim_time}ns-hysteresis",
    Hsteps=[[(0, 0, 0), Hmax, 10], [Hmax, Hmin, 10], [Hmin, Hmax, 20]]
)
# Out:
# Running OOMMF (ExeOOMMFRunner)[2025/07/30 15:40]... (298.6 s)

# %%
system.table.mpl(
    x="Bz_hysteresis", y=["mz"], marker="o", linewidth=2, linestyle="dashed"
)

# %%
oc.Xf_ThermHeunEvolver()._allowed_attributes
# Out:
# ['alpha',
#  'gamma_LL',
#  'gamma_G',
#  'do_precess',
#  'allow_signed_gamma',
#  'min_timestep',
#  'max_timestep',
#  'fixed_spins',
#  'start_dm',
#  'start_dt',
#  'stage_start',
#  'error_rate',
#  'absolute_step_error',
#  'relative_step_error',
#  'energy_precision',
#  'min_step_headroom',
#  'max_step_headroom',
#  'reject_goal',
#  'method',
#  'temperature',
#  'tempscript',
#  'tempscript_args',
#  'uniform_seed']

# %%
oc.TimeDriver()._allowed_attributes
# Out:
# ['evolver',
#  'stopping_dm_dt',
#  'stage_iteration_limit',
#  'total_iteration_limit',
#  'stage_count_check',
#  'checkpoint_file',
#  'checkpoint_interval',
#  'checkpoint_disposal',
#  'start_iteration',
#  'start_stage',
#  'start_stage_iteration',
#  'start_stage_start_time',
#  'start_stage_elapsed_time',
#  'start_last_timestep',
#  'normalize_aveM_output',
#  'report_max_spin_angle',
#  'report_wall_time']

# %%
mm.__version__
# Out:
# '0.64.0'
